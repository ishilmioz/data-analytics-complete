# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
user_input = input("Enter something:")
print(f"{user_input}")
# Out:
# Ismail Hilmi

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
number = int(input("Enter a number:"))
if number > 0:
    print(f"{number} is positive.")
elif number < 0:
    print(f"{number} is negative.")
else:
    print(f"{number} is zero.")
# Out:
# 1881 is positive.

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
num1 = int(input("Enter the 1st number:"))
num2 = int(input("Enter the 2nd number:"))
num3 = int(input("Enter the 3rd number:"))

if (num1 > num2) and (num1>num3):
    largest = num1
elif (num2>num1) and (num2>num3):
    largest = num2
else:
    largest = num3

print(f"Largest is: {largest}")
# Out:
# Largest is: 1923

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
def factorial (n):
    if n == 0:
        return 1
    else:
        n = n * factorial(n-1)
        return n

number = int(input("Enter a number to calculate the factorial."))
print (f"Factorial is: {factorial(number)}")
# Out:
# Factorial is: 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
age = 28
pi = 3.14
name = "Ismail"
is_student = True

print (age)
print (pi)
print (name)
print (is_student)

print (type(age))
print (type(pi))
print (type(name))
print (type(is_student))

print(f"Type of {age} is {type(age)}")
print(f"Type of {pi} is {type(pi)}")
print(f"Type of {name} is {type(name)}")
print(f"Type of {is_student} is {type(is_student)}")
# Out:
# 28
# 3.14
# Ismail
# True
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# Type of 28 is <class 'int'>
# Type of 3.14 is <class 'float'>
# Type of Ismail is <class 'str'>
# Type of True is <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
a = 10
b = 5

print(f"Before swapping: a = {a} : b = {b}")

a , b = b , a

print(f"After swapping: a = {a} : b = {b}")
# Out:
# Before swapping: a = 10 : b = 5
# After swapping: a = 5 : b = 10

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
celcius = float(input("Enter celcius degree to calculate fahrenheit."))
fahrenheit = ((celcius * 9/5) + 32)

print(f"{celcius} celcius is {fahrenheit} fahrenheit.")
# Out:
# 5.0 celcius is 41.0 fahrenheit.

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
str1 = "Ismail"
str2 = "Hilmi"
concatstr = str1 + " " + str2

print(f"{concatstr}")
# Out:
# Ismail Hilmi

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
str3 = "Ozcelik"

if isinstance(str3,str):
    print(f"{str3} is a string.")
else:
    print(f"{str3} is not a string.")
# Out:
# Ozcelik is a string.

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
a = 10
b = 5

print(f"Addition of a and b is {a+b}")
print(f"Substraction of a and b is {a-b}")
print(f"Multiplication of a and b is {a*b}")
print(f"Division of a and b is {a/b}")
# Out:
# Addition of a and b is 15
# Substraction of a and b is 5
# Multiplication of a and b is 50
# Division of a and b is 2.0

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
a = 10
b = 5

print(f"A = B : {a==b}")
print(f"A != B : {a!=b}")
print(f"A > B : {a>b}")
print(f"A < B : {a<b}")
# Out:
# A = B : False
# A != B : True
# A > B : True
# A < B : False

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
is_x = True
is_y = False

print(f"X and Y: {is_x and is_y}")
print(f"X or Y: {is_x or is_y}")
print(f"not X: {not is_x}")
print(f"not Y: {not is_y}")
# Out:
# X and Y: False
# X or Y: True
# not X: False
# not Y: True

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
number = int(input("Enter a number: "))
square = number ** 2

print(f"square of {number} is {square}.")
# Out:
# square of 5 is 25.

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
number = int(input("Enter a number: "))
if number % 2 == 0:
    print(f"{number} is even.")
else:
    print(f"{number} is odd.")
# Out:
# -4 is even.

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
number = int(input("Enter a number: "))
sum_of_natural = ((number * (number + 1)) / 2)
print(f"sum is: {sum_of_natural}")
# Out:
# sum is: 15.0

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
year = int(input("Enter a year: "))

if (year %4 == 0 or year % 100 == 0) or (year % 400 == 0):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# 2010 is not a leap year.

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
str4 = input("Enter a string:")
rvrsdstr = str4[::-1]

print(f"Reversed version of {str4} is {rvrsdstr}")
# Out:
# Reversed version of Türkiye is eyikrüT

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
str5 = input ("Enter a string: ")
if str5 == str5[::-1]:
    print(f"{str5} is palindrome.")
else:
    print(f"{str5} is not palindrome.")
# Out:
# RADAR is palindrome.

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
numbers = [int(a) for a in input("Enter numbers with spaces:").split()]
numbers.sort()

print(f"sorted list: {numbers}")
# Out:
# sorted list: [6, 8, 90, 100]
